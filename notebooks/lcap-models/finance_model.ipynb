# %%
import pandas as pd
import numpy as np
import plotly.express as px
# Out:
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
file_name = '../data/historical_data_eikon.xlsx'
df = pd.read_excel(file_name)
df
# Out:
#        Instrument                  Date  \
# 0         SRCE.OQ  1984-12-31T00:00:00Z
# 1         SRCE.OQ  1984-12-31T00:00:00Z
# 2         SRCE.OQ  1984-12-31T00:00:00Z
# 3         SRCE.OQ  1984-12-31T00:00:00Z
# 4         SRCE.OQ  1984-12-31T00:00:00Z
# ...           ...                   ...
# 118906     ZURN.S  2017-12-31T00:00:00Z
# 118907     ZURN.S  2018-12-31T00:00:00Z
# 118908     ZURN.S  2019-12-31T00:00:00Z
# 118909     ZURN.S  2020-12-31T00:00:00Z
# 118910     ZURN.S  2021-12-31T00:00:00Z
#
#         Return on Capital, Total LT Capital, Percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 118906                                           NaN
# 118907                                           NaN
# 118908                                           NaN
# 118909                                           NaN
# 118910                                           NaN
#
#         Cash from Operating Activities  Total Common Shares Outstanding  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 118906                    5.206000e+09                      150183280.0
# 118907                    4.388000e+09                      147265600.0
# 118908                    4.884000e+09                      148058310.0
# 118909                    5.701000e+09                      148496060.0
# 118910                    3.168000e+09                      148290970.0
#
#         Long Term Debt to Total Capital, Percent
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 118906                                 23.609256
# 118907                                 27.415894
# 118908                                 27.170768
# 118909                                 28.046460
# 118910                                 29.848461
#
# [118911 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df
# Out:
#        Instrument                      Date  \
# 0         SRCE.OQ 1984-12-31 00:00:00+00:00
# 1         SRCE.OQ 1984-12-31 00:00:00+00:00
# 2         SRCE.OQ 1984-12-31 00:00:00+00:00
# 3         SRCE.OQ 1984-12-31 00:00:00+00:00
# 4         SRCE.OQ 1984-12-31 00:00:00+00:00
# ...           ...                       ...
# 118906     ZURN.S 2017-12-31 00:00:00+00:00
# 118907     ZURN.S 2018-12-31 00:00:00+00:00
# 118908     ZURN.S 2019-12-31 00:00:00+00:00
# 118909     ZURN.S 2020-12-31 00:00:00+00:00
# 118910     ZURN.S 2021-12-31 00:00:00+00:00
#
#         Return on Capital, Total LT Capital, Percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 118906                                           NaN
# 118907                                           NaN
# 118908                                           NaN
# 118909                                           NaN
# 118910                                           NaN
#
#         Cash from Operating Activities  Total Common Shares Outstanding  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 118906                    5.206000e+09                      150183280.0
# 118907                    4.388000e+09                      147265600.0
# 118908                    4.884000e+09                      148058310.0
# 118909                    5.701000e+09                      148496060.0
# 118910                    3.168000e+09                      148290970.0
#
#         Long Term Debt to Total Capital, Percent    Year
# 0                                            NaN  1984.0
# 1                                            NaN  1984.0
# 2                                            NaN  1984.0
# 3                                            NaN  1984.0
# 4                                            NaN  1984.0
# ...                                          ...     ...
# 118906                                 23.609256  2017.0
# 118907                                 27.415894  2018.0
# 118908                                 27.170768  2019.0
# 118909                                 28.046460  2020.0
# 118910                                 29.848461  2021.0
#
# [118911 rows x 7 columns]

# %%
df = df[df["Cash from Operating Activities"] != 0]
df
# Out:
#        Instrument                      Date  \
# 0         SRCE.OQ 1984-12-31 00:00:00+00:00
# 1         SRCE.OQ 1984-12-31 00:00:00+00:00
# 2         SRCE.OQ 1984-12-31 00:00:00+00:00
# 3         SRCE.OQ 1984-12-31 00:00:00+00:00
# 4         SRCE.OQ 1984-12-31 00:00:00+00:00
# ...           ...                       ...
# 118906     ZURN.S 2017-12-31 00:00:00+00:00
# 118907     ZURN.S 2018-12-31 00:00:00+00:00
# 118908     ZURN.S 2019-12-31 00:00:00+00:00
# 118909     ZURN.S 2020-12-31 00:00:00+00:00
# 118910     ZURN.S 2021-12-31 00:00:00+00:00
#
#         Return on Capital, Total LT Capital, Percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 118906                                           NaN
# 118907                                           NaN
# 118908                                           NaN
# 118909                                           NaN
# 118910                                           NaN
#
#         Cash from Operating Activities  Total Common Shares Outstanding  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 118906                    5.206000e+09                      150183280.0
# 118907                    4.388000e+09                      147265600.0
# 118908                    4.884000e+09                      148058310.0
# 118909                    5.701000e+09                      148496060.0
# 118910                    3.168000e+09                      148290970.0
#
#         Long Term Debt to Total Capital, Percent    Year
# 0                                            NaN  1984.0
# 1                                            NaN  1984.0
# 2                                            NaN  1984.0
# 3                                            NaN  1984.0
# 4                                            NaN  1984.0
# ...                                          ...     ...
# 118906                                 23.609256  2017.0
# 118907                                 27.415894  2018.0
# 118908                                 27.170768  2019.0
# 118909                                 28.046460  2020.0
# 118910                                 29.848461  2021.0
#
# [118891 rows x 7 columns]

# %%
grouped_df = df.groupby("Instrument")

# %%
df['Last OCF'] = grouped_df["Cash from Operating Activities"].shift(1)
df['Change OCF (%)'] = df['Cash from Operating Activities'] / df['Last OCF'] # Atual / Anterior
# Out:
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/2321731640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last OCF'] = grouped_df["Cash from Operating Activities"].shift(1)
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/2321731640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Change OCF (%)'] = df['Cash from Operating Activities'] / df['Last OCF'] # Atual / Anterior

# %%
df['Last shares'] = grouped_df['Total Common Shares Outstanding'].shift(1)
df['Change Shares (%)'] = (df['Total Common Shares Outstanding'] / df['Last shares']) # Atual / Anterior
# Out:
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/480226243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last shares'] = grouped_df['Total Common Shares Outstanding'].shift(1)
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/480226243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Change Shares (%)'] = (df['Total Common Shares Outstanding'] / df['Last shares']) # Atual / Anterior

# %%
df['Year of Last Data'] = df['Year'] - 1
# Out:
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/3935541095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year of Last Data'] = df['Year'] - 1

# %%
df = df.dropna() # Por uma falta de dados, algumas empresas ficam de fora e não são consideradas no modelo

# %%
grouped_df_year = df.groupby(["Instrument", "Year"])

# %%
df['Average Change OCF (%)'] = grouped_df_year['Change OCF (%)'].transform('mean')
df['Average Change Shares (%)'] = grouped_df_year['Change Shares (%)'].transform('mean')
# Out:
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/1389126751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average Change OCF (%)'] = grouped_df_year['Change OCF (%)'].transform('mean')
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/1389126751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average Change Shares (%)'] = grouped_df_year['Change Shares (%)'].transform('mean')

# %%
ranked_df = df[['Instrument', 'Date', 'Year', 'Return on Capital, Total LT Capital, Percent', 
                'Long Term Debt to Total Capital, Percent', 'Average Change Shares (%)', 'Average Change OCF (%)']].copy()

# %%
ranked_df['ROIC Rank'] = ranked_df.groupby('Year')['Return on Capital, Total LT Capital, Percent'].rank(ascending=False)
ranked_df['Debt Rank'] = ranked_df.groupby('Year')['Long Term Debt to Total Capital, Percent'].rank(ascending=True)
ranked_df['Average OCF Change Rank'] = ranked_df.groupby('Year')['Average Change OCF (%)'].rank(ascending=False)
ranked_df['Average Shares Change Rank'] = ranked_df.groupby('Year')['Average Change Shares (%)'].rank(ascending=True)

# %%
ranked_df['Average Rank'] = ranked_df[['ROIC Rank', 'Debt Rank', 'Average OCF Change Rank', 'Average Shares Change Rank']].mean(axis=1)

# %%
ranked_df = ranked_df.sort_values(by=['Year', 'Average Rank'])

# %%
dataframes = {year: grouped_df for year, grouped_df in ranked_df.groupby('Year')}

# %%
df_2000 = dataframes[2000]
df_2000
# Out:
#        Instrument                      Date    Year  \
# 55343       HGT.L 2000-12-31 00:00:00+00:00  2000.0
# 54308     HCLT.NS 2000-06-30 00:00:00+00:00  2000.0
# 32029     CRVL.OQ 2000-03-31 00:00:00+00:00  2000.0
# 60512     INFY.NS 2000-03-31 00:00:00+00:00  2000.0
# 116631      WIT.N 2000-03-31 00:00:00+00:00  2000.0
# ...           ...                       ...     ...
# 50266          GS 2000-11-24 00:00:00+00:00  2000.0
# 83450     PCEN.SI 2000-12-31 00:00:00+00:00  2000.0
# 23099    CTLPP.PK 2000-06-30 00:00:00+00:00  2000.0
# 39737   E2EF34.SA 2000-12-31 00:00:00+00:00  2000.0
# 39738   E2EF34.SA 2000-12-31 00:00:00+00:00  2000.0
#
#         Return on Capital, Total LT Capital, Percent  \
# 55343                                      20.565300
# 54308                                      27.371168
# 32029                                      20.986269
# 60512                                      40.625388
# 116631                                     59.700652
# ...                                              ...
# 50266                                       2.639085
# 83450                                     -70.717232
# 23099                                    -420.144964
# 39737                                     -89.850449
# 39738                                     -89.850449
#
#         Long Term Debt to Total Capital, Percent  Average Change Shares (%)  \
# 55343                                   0.000000                   0.971262
# 54308                                   0.052824                   0.561388
# 32029                                   0.000000                   0.951754
# 60512                                   0.000000                   1.000180
# 116631                                  2.486855                   0.994692
# ...                                          ...                        ...
# 50266                                  25.816770                   1.077106
# 83450                                  18.310228                   1.006879
# 23099                                  98.695179                   2.160479
# 39737                                 194.178628                   1.085499
# 39738                                 194.178628                   1.085499
#
#         Average Change OCF (%)  ROIC Rank  Debt Rank  Average OCF Change Rank  \
# 55343                 4.043943       37.0       22.0                     10.0
# 54308                 1.875172       24.0       45.0                     25.0
# 32029                 1.245861       35.0       22.0                     54.0
# 60512                 1.570347       11.0       22.0                     33.0
# 116631                1.489200        7.0       55.0                     39.0
# ...                        ...        ...        ...                      ...
# 50266                -0.127651       97.0      103.0                    119.0
# 83450               -13.353642      132.0       88.0                    134.0
# 23099                 1.456091      136.0      133.0                     41.0
# 39737                 0.894984      134.5      134.5                     78.5
# 39738                 0.894984      134.5      134.5                     78.5
#
#         Average Shares Change Rank  Average Rank
# 55343                         18.0         21.75
# 54308                          2.0         24.00
# 32029                          7.0         29.50
# 60512                         64.0         32.50
# 116631                        36.0         34.25
# ...                            ...           ...
# 50266                        111.0        107.50
# 83450                         78.0        108.00
# 23099                        133.0        110.75
# 39737                        112.5        115.00
# 39738                        112.5        115.00
#
# [136 rows x 12 columns]

# %% [markdown]
# ## EACH YEAR BACKTEST

# %%
prices_df_1 = pd.read_excel('../data/prices.xlsx', usecols=[0,1,2])

# %%
prices_df_2 = pd.read_excel('../data/prices.xlsx', usecols=[4,5,6])

# %%
prices_df_3 = pd.read_excel('../data/prices.xlsx', usecols=[8,9,10])

# %%
prices_df_1.columns = ['Instrument', 'Date', 'Price Close']
prices_df_2.columns = ['Instrument', 'Date', 'Price Close']
prices_df_3.columns = ['Instrument', 'Date', 'Price Close']

prices_df = pd.concat([prices_df_1, prices_df_2, prices_df_3]).reset_index(drop=True)

# %%
prices_df_nan = prices_df.dropna()
prices_df_nan
# Out:
#         Instrument                  Date  Price Close
# 0          SRCE.OQ  1990-01-04T00:00:00Z     2.998465
# 1          SRCE.OQ  1990-01-12T00:00:00Z     2.932435
# 2          SRCE.OQ  1990-01-19T00:00:00Z     2.932435
# 3          SRCE.OQ  1990-01-25T00:00:00Z     2.767824
# 4          SRCE.OQ  1990-02-02T00:00:00Z     2.827000
# ...            ...                   ...          ...
# 2216763     ZURN.S  2023-06-23T00:00:00Z   424.800000
# 2216764     ZURN.S  2023-06-30T00:00:00Z   424.900000
# 2216765     ZURN.S  2023-07-07T00:00:00Z   410.500000
# 2216766     ZURN.S  2023-07-14T00:00:00Z   409.800000
# 2216767     ZURN.S  2023-07-21T00:00:00Z   424.200000
#
# [1100803 rows x 3 columns]

# %%
backtest_results = {}

# %%
def plot_yearly_portfolio(year):
    df_year = dataframes[year]

    total_companies = len(df_year)
    beta = 75 # Valor alterado para cada ano, a fim de se obter 15 empresas

    weights = (1 - (df_year['Average Rank'] - 1) / (total_companies - 1)) ** beta
    normalized_weights = weights / weights.sum()

    capital_allocation_percentage = normalized_weights * 100

    df_year['Capital Allocation (%)'] = capital_allocation_percentage.apply(lambda x: round(x,3))

    initial_investment = 100000 

    filtered_allocation = df_year[df_year['Capital Allocation (%)'] > 0]
    filtered_allocation['Allocation Amount'] = initial_investment / 100 * filtered_allocation['Capital Allocation (%)']

    tickers = filtered_allocation['Instrument'].to_list()
    amount = filtered_allocation['Allocation Amount'].to_list()

    dic = dict(zip(tickers, amount))

    prices_df_filtered = prices_df_nan[prices_df_nan['Instrument'].isin(tickers)]
    prices_df_filtered['Date'] = pd.to_datetime(prices_df_filtered['Date'], format='%Y-%m-%d')

    prices_df_filtered = prices_df_filtered[prices_df_filtered['Date'].dt.year == year]

    prices_df_filtered['Initial Investment'] = prices_df_filtered['Instrument'].map(dic)

    first_prices = prices_df_filtered.groupby('Instrument')['Price Close'].first()
    first_prices_dict = first_prices.to_dict()

    prices_df_filtered['First Price'] = prices_df_filtered['Instrument'].map(first_prices_dict)
    prices_df_filtered['Shares'] = prices_df_filtered['Initial Investment'] / prices_df_filtered['First Price']

    prices_df_filtered['Investment Value'] = prices_df_filtered['Price Close'] * prices_df_filtered['Shares']

    portfolio_df = prices_df_filtered.drop_duplicates(subset=['Instrument'], keep='last')

    final_portfolio_value = portfolio_df['Investment Value'].sum()

    backtest_results[year] = final_portfolio_value

    prices_df_filtered.set_index('Date', inplace=True)

    portfolio_value_by_week = prices_df_filtered.resample('W')['Investment Value'].sum().reset_index()
    
    start_date = f"{year}-01-01"
    end_date = f"{year}-12-31"
    
    data = yf.download('^GSPC', start=start_date, end=end_date)

    data['Return'] = data['Close'].pct_change()
    data['Cumulative Return'] = (1 + data['Return']).cumprod()
    data['Investment Value'] = initial_investment * data['Cumulative Return']
    
    fig, ax = plt.subplots()
    ax.plot(portfolio_value_by_week['Date'], portfolio_value_by_week['Investment Value'], label='Portfolio')
    ax.plot(data.index, data['Investment Value'], label='S&P500')
    ax.set_xlabel('Date')
    ax.set_ylabel('Investment Value')
    ax.set_title(f'Portfolio Value and S&P 500 Over Time for {year}')
    ax.legend()

    plt.show()

    profitability = (final_portfolio_value - initial_investment) / initial_investment
    sp_profitability = (data['Investment Value'].iloc[-1] - initial_investment) / initial_investment  # SP500 return

    print(f"The {year} portfolio's profitability is {profitability * 100 :.2f}%.")
    print(f"The S&P 500's profitability for the year {year} is {sp_profitability * 100 :.2f}%.")
    print(f"The final portfolio value for the year {year} is ${final_portfolio_value :.2f}.")
    
    return len(portfolio_df)

# %%
plot_yearly_portfolio(2020)
# Out:
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/305614129.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_allocation['Allocation Amount'] = initial_investment / 100 * filtered_allocation['Capital Allocation (%)']
# /var/folders/4z/8f0cq10x723_s3xz_r8c50q80000gn/T/ipykernel_1473/305614129.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df_filtered['Date'] = pd.to_datetime(prices_df_filtered['Date'], format='%Y-%m-%d')
# [*********************100%***********************]  1 of 1 completed
# The 2020 portfolio's profitability is 56.54%.
# The S&P 500's profitability for the year 2020 is 14.56%.
# The final portfolio value for the year 2020 is $156539.54.
# 15
